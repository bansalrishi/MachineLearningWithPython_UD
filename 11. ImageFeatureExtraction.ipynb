# %% [markdown]
# # Agenda
#
# 1. Concept
# 2. Images in Numeric Form
# 3. Image Preprocessing
# 4. Loading/Reading, Writing and Displaying Images
# 5. Resize, Conversion to Grayscale
# 6. Edge Detection
# 7. Face Detection
# 8. Histogram Equalization

# %% [markdown]
# # 1. Computer Vision
# - allows computers to understand and label images
# - machines use deep learning models to identify and classify objects, obtained from cameras and videos
# E.g: Robotics, convenience stores, Medicine, driverless car testing, daily medical diagnostics, monitoring the health of crops and livestock
#
# OpenCV == Open Source Computer Vision Library

# %% [markdown]
# #  2. Images in Numeric Form
# ##### Obtaining pixel intensities for image and transforming those into usable features
# Each pixel holds a value based on the type of image
#
#     RGB Images: R, G, B: 0 -255
#     R(255,0,0), G(0,255,0), B(0,0,255)
#     3 channels as each pixel need 3 values to represent information
#
# <img src="Image/FG.JPG" width="300" />
# <img src="Image/pixel.png" width="500" />
#
#     Grayscale Images: Each pixel represents only intensity information 0 (black) to 255 (white)
#     1 channel image
#
# <img src="Image/bw.png" width="500" />

# %% [markdown]
# # 3. Image Preprocessing
# - to make the image ready for ML model
# - standardize the image
# - to reduce complexity and increase efficiency of the algorithm
#
# Image Preprocessing Techniques:
# 1. Color Image to Grayscale to reduce size/complexity
# 2. Standardize images (identical widths and heights before feeding into CNN)
# 3. Data augmentation
# In order to enlarge the dataset and expose Neural Network to various variations of the images.
# E.g: Scaling, Rotation, De-colorizing, Edge Enhancing, etc

# %% [markdown]
# # 4. Loading/Reading, Writing and Displaying Images
# imread()
# imwrite()
# imshow()

# %%
import cv2, os
import matplotlib.pyplot as plt
imagePath = 'Image/beach.jpg'

#read
image = cv2.imread(imagePath)

#Write
cv2.imwrite('Image/beach.png',image)

#Display/Show
plt.imshow(image)

# %%
#The Default color mode in OpenCV is BGR, which is different from Matplotlib. 
#So, we need to change it to RGB 
img_rgb = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)
plt.imshow(img_rgb)
print(img_rgb.shape)
print(img_rgb[0][0])
# Out:
# (289, 606, 3)
# [  1 114 180]

# %% [markdown]
# # 5. Resize, Conversion to Grayscale

# %%
#Scale this image to a smaller size
size=(64, 64)
resized_image_feature_vector = cv2.resize(img_rgb, size)
plt.imshow(resized_image_feature_vector)

# %%
print(resized_image_feature_vector.shape)
# Out:
# (64, 64, 3)

# %% [markdown]
# #### Image array can be flattened into a one-dimensional array

# %%
resized_flattened_image_feature_vector = resized_image_feature_vector.flatten()
print(len(resized_flattened_image_feature_vector))
#image_grayscale = cv2.imread(imagePath, cv2.IMREAD_GRAYSCALE )
image_grayscale = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY )
plt.imshow(image_grayscale)
# Out:
# 12288

# %%
image_grayscale.shape
# Out:
# (289, 606)

# %%
image_grayscale
# Out:
# array([[154, 155, 158, ..., 216, 216, 216],
#        [153, 154, 156, ..., 216, 216, 216],
#        [152, 153, 154, ..., 216, 216, 216],
#        ...,
#        [123, 123, 123, ..., 112, 112, 112],
#        [123, 123, 123, ..., 112, 112, 112],
#        [123, 123, 123, ..., 112, 112, 112]], dtype=uint8)

# %% [markdown]
# # 6. Edge Detection

# %%
import cv2, os
import matplotlib.pyplot as plt
imagePath = 'Image/beach.jpg'

#read
image = cv2.imread(imagePath)

plt.imshow(cv2.Canny(image,200,300))

# %% [markdown]
# # 7. Face Detection

# %%
import cv2, os
import matplotlib.pyplot as plt
import numpy as np
imagePath = 'Image/face.jpg'

#read

face_detection=cv2.CascadeClassifier('Data/opencv/haarcascades/haarcascade_frontalface_alt.xml')
image = cv2.imread(imagePath)
gray = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)
faces = face_detection.detectMultiScale(gray, 1.3, 5)
for (x,y,w,h) in faces:
    img = cv2.rectangle(image,(x,y),(x+w, y+h),(255,0,0),3)
plt.imshow(img)

# %% [markdown]
# # 8.Eye Detection

# %%
import cv2, os
import matplotlib.pyplot as plt
import numpy as np
imagePath = 'Image/face.jpg'

eye_detection=cv2.CascadeClassifier('Data/opencv/haarcascades/haarcascade_eye.xml')
image = cv2.imread(imagePath)
gray = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)
eyes = eye_detection.detectMultiScale(gray, 1.03, 5)
for (ex,ey,ew,eh) in eyes:
    img = cv2.rectangle(image,(ex,ey),(ex+ew, ey+eh),(0,255,0),2)
plt.imshow(img)
